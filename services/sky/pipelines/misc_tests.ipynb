# %%
from astroquery.jplhorizons import Horizons

site = {"lon": 21.0122, "lat": 52.2297, "elevation": 0.10}

obj = Horizons(
    id="2026 DK",
    id_type="smallbody",
    location=site,
    epochs=2461094.367193102
)

tab = obj.ephemerides(quantities="1,4,9,10")
print(tab)
# Out:
# targetname       datetime_str       ...   surfbright  illumination
#    ---               ---            ... mag / arcsec2      %
# ---------- ------------------------ ... ------------- ------------
#  (2026 DK) 2026-Feb-22 20:48:45.484 ...            --     37.53297
